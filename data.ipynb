# %%
# !pip install pandas openpyxl bcrypt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 26.1 MB/s  0:00:00m0:00:010:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.7/16.7 MB 41.6 MB/s  0:00:006m0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5/5 [openpyxl]4/5 [openpyxl]
# ...
#
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: python3 -m pip install --upgrade pip

# %%
import pandas as pd
import bcrypt

# %%
df=pd.read_csv("voters_jude.csv")
df.head()
# Out:
#     lastName         firstName voter_id  password    class    photo
# 0     AKELLO   JACKINE PAMELLA    S1001      1001  S1_EAST  non.jpg
# 1   ATUGONZA     MARIA DAPHINE    S1002      1002  S1_EAST  non.jpg
# 2    BABIRYE  ROLINDA NAJJINGO    S1003      1003  S1_EAST  non.jpg
# 3  BABYESIZA             DAVID    S1004      1004  S1_EAST  non.jpg
# 4    BUKIRWA            JULIET    S1005      1005  S1_EAST  non.jpg

# %%
def hash_password(password):
    password = str(password).strip()
    hashed = bcrypt.hashpw(password.encode('utf-8'), bcrypt.gensalt())
    return hashed.decode('utf-8')

df['password'] = df['password'].apply(hash_password)

# %%
df.head()
# Out:
#     lastName         firstName voter_id  \
# 0     AKELLO   JACKINE PAMELLA    S1001
# 1   ATUGONZA     MARIA DAPHINE    S1002
# 2    BABIRYE  ROLINDA NAJJINGO    S1003
# 3  BABYESIZA             DAVID    S1004
# 4    BUKIRWA            JULIET    S1005
#
#                                             password    class    photo
# 0  $2b$12$YjXMGL/6.yfxya38sCwYmu8vn/FG/EJrvGKw17e...  S1_EAST  non.jpg
# 1  $2b$12$mJEduFi4vuucQycImJQJDeNumTsIMAO4iEGfakO...  S1_EAST  non.jpg
# 2  $2b$12$JcTALtWFjpl/AaLKpjF4ou5f6gOdbFg/wADbb7j...  S1_EAST  non.jpg
# 3  $2b$12$4KFH4gXBLe2T49cG0YBhD.D8/W3gv4FfbwDZ.K8...  S1_EAST  non.jpg
# 4  $2b$12$tUqujY76y29Ju20YVpljsOp.bI9we2Qw1Q7p5mA...  S1_EAST  non.jpg

# %%
df.to_csv("voters_hashed.csv", index=False)
